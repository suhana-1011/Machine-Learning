# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd

# %%
df=pd.read_csv("C:\\Users\\USER\\Downloads\\ml\\Ice_cream selling data.csv")

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 49 entries, 0 to 48
# Data columns (total 2 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Temperature (°C)         49 non-null     float64
#  1   Ice Cream Sales (units)  49 non-null     float64
# dtypes: float64(2)
# memory usage: 916.0 bytes

# %%
plt.scatter(df['Temperature (°C)'],df['Ice Cream Sales (units)'])

# %%
df.corr() #check the relation between feature and target is linear or non linear
# Out:
#                          Temperature (°C)  Ice Cream Sales (units)
# Temperature (°C)                 1.000000                -0.175184
# Ice Cream Sales (units)         -0.175184                 1.000000

# %%
from sklearn.linear_model import LinearRegression

# %%
x=df[['Temperature (°C)']]
y=df['Ice Cream Sales (units)']

# %%
model=LinearRegression()

# %%
model.fit(x,y)
# Out:
# LinearRegression()

# %%
model.predict(x)
# Out:
# array([19.83504165, 19.55970386, 19.47800752, 19.26748505, 18.97191395,
#        18.87407555, 18.59748863, 18.57587533, 18.25024982, 18.23418207,
#        18.23355385, 17.94425352, 17.80376302, 17.57045518, 17.44414515,
#        17.17815336, 17.05609176, 16.7376736 , 16.6583646 , 16.24092715,
#        16.15054649, 16.14874553, 16.11489373, 16.00288249, 15.57316494,
#        15.56932764, 15.42492506, 15.3060333 , 15.1335758 , 15.03871692,
#        14.73591401, 14.64786415, 14.52938443, 14.46902077, 14.27509091,
#        14.15295043, 13.90374659, 13.86637384, 13.76429043, 13.71575256,
#        13.56403399, 13.51729954, 13.48063985, 13.4648223 , 13.2459192 ,
#        13.17162651, 12.83169023, 12.82956701, 12.21988091])

# %%
slope=model.coef_
slope
# Out:
# array([-0.79645711])

# %%
intercept=model.intercept_
intercept
# Out:
# np.float64(16.121749391993667)

# %%
from sklearn.model_selection import train_test_split

# %%
x=df[['Temperature (°C)']]
y=df['Ice Cream Sales (units)']

# %%
train_test_split(x,y,train_size=0.8)
# Out:
# [    Temperature (°C)
#  17         -0.773330
#  43          3.335932
#  32          1.999310
#  33          2.075101
#  40          3.211366
#  48          4.899032
#  4          -3.578554
#  39          3.020874
#  42          3.316073
#  24          0.688781
#  35          2.471946
#  31          1.850552
#  16         -1.173123
#  2          -4.213985
#  44          3.610778
#  23          0.149245
#  5          -3.455712
#  37          2.831760
#  1          -4.316559
#  3          -3.949661
#  11         -2.288264
#  28          1.240712
#  9          -2.652287
#  47          4.133534
#  34          2.318591
#  26          0.874905
#  13         -1.818938
#  25          0.693599
#  30          1.740000
#  18         -0.673753
#  12         -2.111870
#  45          3.704057
#  38          2.959932
#  36          2.784836
#  46          4.130868
#  20         -0.036156
#  10         -2.651498
#  19         -0.149635
#  0          -4.662263,
#      Temperature (°C)
# ...

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.8,random_state=40)

# %%
print(y_train)
print(y_train.shape)
print(x_test)
print(y_test)
# Out:
# 34     7.412094
# 21     0.897603
# 18     5.210163
# 43    26.104740
# 24     2.576782
# 25     4.625689
# 40    22.839406
# 5     30.001138
# 13    10.012868
# 38    21.342916
# 17     9.392969
# 42    25.142082
# 23     1.931416
# 3     37.539845
# 22     3.165600
# 39    20.114413
# 26     0.789974
# 33     8.170735
# 20     0.328626
# 28     1.292361
# 14    12.615181
# 15    10.957731
# 30     3.782570
# 8     19.226970
# 36    15.996620
# 32     8.943823
# 9     20.279679
# 47    27.698383
# 41    16.983279
# 10    13.275828
# 31     4.857988
# 19     4.673643
# 46    34.530743
# 12    11.218294
# 1     34.661120
# 37    12.568237
# 7     25.365022
# 27     2.313806
# 6     22.635401
# Name: Ice Cream Sales (units), dtype: float64
# (39,)
#     Temperature (°C)
# 48          4.899032
# 16         -1.173123
# 29          1.359813
# 44          3.610778
# 0          -4.662263
# 4          -3.578554
# 45          3.704057
# 11         -2.288264
# 2          -4.213985
# ...

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(x_train)

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import root_mean_squared_error
from sklearn.metrics import r2_score

# %%
y_pred_train=model.predict(x_train)

# %%
train_score = r2_score(y_train, y_pred_train)
print(train_score)
# Out:
# 0.015234241349056155

# %%
y_pred_test=model.predict(x_test)

# %%
test_score = r2_score(y_test, y_pred_test)
print(test_score)
# Out:
# -0.4122082415321706

# %%
from sklearn.preprocessing import PolynomialFeatures
poly=PolynomialFeatures(degree=3)
updated_xtrain=poly.fit_transform(x_train)
updated_xtest=poly.transform(x_test)

# %%
updated_xtrain
# Out:
# array([[ 1.00000000e+00,  2.31859124e+00,  5.37586534e+00,
#          1.24644343e+01],
#        [ 1.00000000e+00, -3.38952856e-02,  1.14889038e-03,
#         -3.89419677e-05],
#        [ 1.00000000e+00, -6.73752802e-01,  4.53942838e-01,
#         -3.05845259e-01],
#        [ 1.00000000e+00,  3.33593241e+00,  1.11284451e+01,
#          3.71237406e+01],
#        [ 1.00000000e+00,  6.88780908e-01,  4.74419139e-01,
#          3.26770845e-01],
#        [ 1.00000000e+00,  6.93598873e-01,  4.81079396e-01,
#          3.33676127e-01],
#        [ 1.00000000e+00,  3.21136614e+00,  1.03128725e+01,
#          3.31184096e+01],
#        [ 1.00000000e+00, -3.45571170e+00,  1.19419433e+01,
#         -4.12679133e+01],
#        [ 1.00000000e+00, -1.81893761e+00,  3.30853403e+00,
#         -6.01801697e+00],
#        [ 1.00000000e+00,  2.95993209e+00,  8.76119799e+00,
#          2.59325511e+01],
#        [ 1.00000000e+00, -7.73330043e-01,  5.98039356e-01,
#         -4.62481801e-01],
# ...

# %%
updated_xtest
# Out:
# array([[   1.        ,    4.89903151,   24.00050977,  117.57925372],
#        [   1.        ,   -1.17312327,    1.3762182 ,   -1.61447359],
#        [   1.        ,    1.35981267,    1.84909051,    2.51441671],
#        [   1.        ,    3.61077848,   13.03772121,   47.07632316],
#        [   1.        ,   -4.66226268,   21.73669327, -101.34217377],
#        [   1.        ,   -3.57855372,   12.8060467 ,  -45.82712601],
#        [   1.        ,    3.70405744,   13.72004151,   50.8198218 ],
#        [   1.        ,   -2.288264  ,    5.23615213,  -11.9816984 ],
#        [   1.        ,   -4.21398476,   17.7576676 ,  -74.83054071],
#        [   1.        ,    2.471946  ,    6.11051701,   15.10486807]])

# %%
model=LinearRegression()
model.fit(updated_xtrain,y_train)
# Out:
# LinearRegression()

# %%
y_pred_train=model.predict(updated_xtrain)
plt.scatter(updated_xtrain[:,1],y_train)
plt.scatter(updated_xtrain[:,1],y_pred_train)

# %%
train_score=r2_score(y_train,y_pred_train)
print(f"Train Score:{train_score}")
# Out:
# Train Score:0.931431475439874

# %%
#test score
y_pred_test=model.predict(updated_xtest)
test_score=r2_score(y_test,y_pred_test)
print(f"Test score: {test_score}")
# Out:
# Test score: 0.9018719148872268

# %% [markdown]
# ### degree=2 ###
#
# ***train score:0.92337946775762 testscore:0.9177516910034225***

# %% [markdown]
# ### degree=3 ###
#
# ***train score:0.931431475439874 testscore:0.9018719148872268***

# %%
from sklearn.preprocessing import PolynomialFeatures

poly = PolynomialFeatures(degree=2)

x_train_poly = poly.fit_transform(x_train)
x_test_poly = poly.transform(x_test)
