# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier ,DecisionTreeRegressor

# %%
df=pd.read_csv('loan_approval_dataset.csv.xls')
x = df.drop(columns='Loan_Approved')
y=df.Loan_Approved

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,train_size=0.8,random_state=42)

# %%
model_1=DecisionTreeClassifier()
model_1=DecisionTreeRegressor() #no concept of purity and impurity and
#it stops the node based on max_depth,min_samples_split=2 ,min_samples_split=1

# %%
DecisionTreeClassifier()
DecisionTreeRegressor
prepro train evaluvate write conclusion metric  dtc use classification
# Out:
#   Cell In[5], line 3
#     prepro train evaluvate write conclusion metric  dtc use classification
#            ^
# SyntaxError: invalid syntax
