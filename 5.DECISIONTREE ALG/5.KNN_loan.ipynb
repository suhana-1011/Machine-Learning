# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier ,KNeighborsRegressor

# %%
df=pd.read_csv('loan_data.csv.xls')
df
# Out:
#        person_age person_gender person_education  person_income  \
# 0            22.0        female           Master        71948.0
# 1            21.0        female      High School        12282.0
# 2            25.0        female      High School        12438.0
# 3            23.0        female         Bachelor        79753.0
# 4            24.0          male           Master        66135.0
# ...           ...           ...              ...            ...
# 44995        27.0          male        Associate        47971.0
# 44996        37.0        female        Associate        65800.0
# 44997        33.0          male        Associate        56942.0
# 44998        29.0          male         Bachelor        33164.0
# 44999        24.0          male      High School        51609.0
#
#        person_emp_exp person_home_ownership  loan_amnt        loan_intent  \
# 0                   0                  RENT    35000.0           PERSONAL
# ...

# %%
x = df.drop(columns='loan_status')
y=df.loan_status

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,train_size=0.8,random_state=42)

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import OrdinalEncoder

# %%
'''preprocessing technique used is onehotencoder  and ordinal encoder'''
# Out:
# 'preprocessing technique used is onehotencoder  and ordinal encoder'

# %%
preprocessing = ColumnTransformer(
    transformers=[
        (
            'onehot_encoder',
            OneHotEncoder(sparse_output=False, handle_unknown='ignore'),
            ['person_gender',
             'person_education',
             'person_home_ownership',
             'loan_intent']
        ),
        (
            'ordinal',
            OrdinalEncoder(categories=[['No', 'Yes']]),
            ['previous_loan_defaults_on_file']
        )
    ],
    remainder='passthrough'
)

# %%
'''we can use 2 parameter
1.n_neighbor=root n 
2. metric=euclidean distance or manhattan
-in knn we use scaling preprocessing technique to get the accuracy and 
we use only for small to medium dataset but not for large datset it will take more time'''
# Out:
# 'we can use 2 parameter\n1.n_neighbor=root n \n2. metric=euclidean distance or manhattan\n-in knn we use scaling preprocessing technique to get the accuracy and \nwe use only for small to medium dataset but not for large datset it will take more time'
