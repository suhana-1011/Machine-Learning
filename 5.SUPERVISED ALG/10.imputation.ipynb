# %%
# Create dataframe with 10 samples
# 1st column: numerical with missing values
# 2nd column: numerical with missing values
# 3rd column: categorical

# %%
import pandas as pd
import numpy as np
from sklearn .impute import SimpleImputer

# %%
x = pd.DataFrame({
    'col_1': [1,2,3,None,None,100,12,95,45,25],
    'col_2': [101,101,451,12,45,123,None,210,234,None],
    'col_3': ['A','A', 'B', 'None', 'C', 'A', 'None', 'D', 'A','None'],
    'col_4': ['AA','AA', 'BB', 'unknown', 'CC', 'AA', 'unknown', 'DD', 'AA','unknown']
})

# %%
print(df)
# Out:
#    col_1  col_2 categorical
# 0    1.0  101.0           A
# 1    2.0  101.0           A
# 2    3.0  451.0           C
# 3    NaN   12.0           B
# 4    NaN   45.0           A
# 5  100.0  123.0           C
# 6   12.0    NaN           B
# 7   95.0  210.0           A
# 8   45.0  234.0           C
# 9   25.0    NaN           A

# %%
x.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   col_1   8 non-null      float64
#  1   col_2   8 non-null      float64
#  2   col_3   10 non-null     str
#  3   col_4   10 non-null     str
# dtypes: float64(2), str(2)
# memory usage: 506.0 bytes

# %%
x['col_3']=x['col_3'].astype('str')

# %%
x.info()
imputer=SimpleImputer(strategy='constant', fill_value='unknown')
imputer.fit_transform(x)
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   col_1   8 non-null      float64
#  1   col_2   8 non-null      float64
#  2   col_3   10 non-null     str
#  3   col_4   10 non-null     str
# dtypes: float64(2), str(2)
# memory usage: 506.0 bytes
# array([[1.0, 101.0, 'A', 'AA'],
#        [2.0, 101.0, 'A', 'AA'],
#        [3.0, 451.0, 'B', 'BB'],
#        ['unknown', 12.0, 'None', 'unknown'],
#        ['unknown', 45.0, 'C', 'CC'],
#        [100.0, 123.0, 'A', 'AA'],
#        [12.0, 'unknown', 'None', 'unknown'],
#        [95.0, 210.0, 'D', 'DD'],
#        [45.0, 234.0, 'A', 'AA'],
#        [25.0, 'unknown', 'None', 'unknown']], dtype=object)

# %%
imputer.transform(x)
# Out:
# array([[1.0, 101.0, 'A', 'AA'],
#        [2.0, 101.0, 'A', 'AA'],
#        [3.0, 451.0, 'B', 'BB'],
#        ['unknown', 12.0, 'None', 'unknown'],
#        ['unknown', 45.0, 'C', 'CC'],
#        [100.0, 123.0, 'A', 'AA'],
#        [12.0, 'unknown', 'None', 'unknown'],
#        [95.0, 210.0, 'D', 'DD'],
#        [45.0, 234.0, 'A', 'AA'],
#        [25.0, 'unknown', 'None', 'unknown']], dtype=object)
