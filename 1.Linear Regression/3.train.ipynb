# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd

# %%
df=pd.read_csv("C:\\Users\\USER\\Downloads\\ml\\train.csv")

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   str
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   str
#  6   Alley          91 non-null     str
#  7   LotShape       1460 non-null   str
#  8   LandContour    1460 non-null   str
#  9   Utilities      1460 non-null   str
#  10  LotConfig      1460 non-null   str
#  11  LandSlope      1460 non-null   str
#  12  Neighborhood   1460 non-null   str
#  13  Condition1     1460 non-null   str
#  14  Condition2     1460 non-null   str
#  15  BldgType       1460 non-null   str
#  16  HouseStyle     1460 non-null   str
#  17  OverallQual    1460 non-null   int64
# ...

# %%
plt.scatter(df['GrLivArea'], df['SalePrice'])

# %% [markdown]
# ###### If your dataset has only numeric columns → df.corr() works directly.
# ###### If your dataset has any text columns → slice only the numeric columns you need before calling .corr().

# %%
df.corr(numeric_only=True)
# Out:
#                      Id  MSSubClass  LotFrontage   LotArea  OverallQual  \
# Id             1.000000    0.011156    -0.010601 -0.033226    -0.028365
# MSSubClass     0.011156    1.000000    -0.386347 -0.139781     0.032628
# LotFrontage   -0.010601   -0.386347     1.000000  0.426095     0.251646
# LotArea       -0.033226   -0.139781     0.426095  1.000000     0.105806
# OverallQual   -0.028365    0.032628     0.251646  0.105806     1.000000
# OverallCond    0.012609   -0.059316    -0.059213 -0.005636    -0.091932
# YearBuilt     -0.012713    0.027850     0.123349  0.014228     0.572323
# YearRemodAdd  -0.021998    0.040581     0.088866  0.013788     0.550684
# MasVnrArea    -0.050298    0.022936     0.193458  0.104160     0.411876
# BsmtFinSF1    -0.005024   -0.069836     0.233633  0.214103     0.239666
# BsmtFinSF2    -0.005968   -0.065649     0.049900  0.111170    -0.059119
# BsmtUnfSF     -0.007940   -0.140759     0.132644 -0.002618     0.308159
# ...

# %%
from sklearn.linear_model import LinearRegression

# %%
x = df[['GrLivArea', 'LotArea', 'OverallQual']]  
y = df['SalePrice']

# %%
model=LinearRegression()

# %%
model.fit(x,y) # it finds the best m and c such that → y = mx + c has minimum error
# Out:
# LinearRegression()

# %%
model.predict(x)
# Out:
# array([218910.00922069, 163969.5300473 , 225300.38669506, ...,
#        251272.7180338 , 121423.24149251, 130615.04483624], shape=(1460,))

# %%
slope=model.coef_
slope
# Out:
# array([5.05131339e+01, 9.11206893e-01, 3.33584831e+04])

# %%
intercept=model.intercept_
intercept
# Out:
# np.float64(-108676.52984514556)

# %%
from sklearn.model_selection import train_test_split

# %%
x = df[['GrLivArea', 'LotArea', 'OverallQual']]  
y = df['SalePrice']

# %%
train_test_split(x,y,train_size=0.8)
# Out:
# [      GrLivArea  LotArea  OverallQual
#  917        1229    17140            4
#  353         720     8520            6
#  1427       1558    10930            5
#  566        2504    11198            9
#  40         1324     8658            6
#  ...         ...      ...          ...
#  763        2365     9430            8
#  396         894     7200            5
#  154        1200    11340            6
#  475         970     8480            5
#  215        1236    10011            5
#
#  [1168 rows x 3 columns],
#        GrLivArea  LotArea  OverallQual
#  646        1048     7200            5
#  936        1200    10083            7
#  484         999     7758            5
#  1297       1072     3675            6
#  641        1929     7050            7
#  ...         ...      ...          ...
#  1241       1689     9849            7
#  677         792     9022            5
#  637        1387     6000            5
#  1235       1784    13132            5
# ...

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.8,random_state=40)

# %%
print(y_train)
print(y_train.shape)
print(x_test)
print(y_test)
# Out:
# 609     118500
# 1361    260000
# 1076    170000
# 1138    196000
# 1159    185000
#          ...
# 1016    203000
# 165     127500
# 7       200000
# 219     167240
# 1350    200000
# Name: SalePrice, Length: 1168, dtype: int64
# (1168,)
#       GrLivArea  LotArea  OverallQual
# 1258       1166     9587            7
# 1041       1632     9130            6
# 1181       1652     5587            8
# 1108       1690     8063            6
# 554        2046    10625            7
# ...         ...      ...          ...
# 711        1178     8712            4
# 1251       1405     3136            7
# 379        1800     8123            6
# 35         2452    13418            8
# 254        1314     8400            5
#
# [292 rows x 3 columns]
# 1258    190000
# 1041    173000
# 1181    392500
# 1108    181000
# 554     284000
#          ...
# 711     102776
# 1251    171750
# 379     179000
# 35      309000
# 254     145000
# Name: SalePrice, Length: 292, dtype: int64

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# step1:corr() or scatterplot()
# step2: x=
#        y=
# step3: train_test_split
# step4: model=linearRegression()
#        #model creation
# step5: model.fit(x_train,y_tarin)mx+c

# %%
# step6:model.predict(new input) error=actual output-predicted output]]

y_pred=model.predict(x_train)

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import root_mean_squared_error
from sklearn.metrics import r2_score

# %%
y_pred_train=model.predict(x_train)

# %%
score = r2_score(y_train, y_pred_train)
print(score)
# Out:
# 0.7266671107998999

# %%
y_pred_train=model.predict(x_test)

# %%
score = r2_score(y_test, y_pred_train)
print(score)
# Out:
# 0.7227893835071724

# %% [markdown]
# ### The model has good performance,[text](<../archive/Ice_cream selling data.csv>)
