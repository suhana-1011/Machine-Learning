# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd

# %%
df=pd.read_csv("C:\\Users\\USER\\Downloads\\ml\\Salary_Data.csv")

# %%
df.info()

# %%
plt.scatter(df['YearsExperience'],df['Salary'])

# %%
df.corr() #check the relation between feature and target is linear or non linear

# %%
from sklearn.linear_model import LinearRegression

# %% [markdown]
# ### step1: feature col always uses 2d array
# * syntax:x=df[['feature']]
# y=df['Target']

# %%
x=df[['YearsExperience']]
y=df['Salary']

# %% [markdown]
# ### step2: it learns the pattern from the input and output cols,mostly we use this method for modeltraining
# * syntax:model=LinearRegression()and model.fit(x_train,y_train)

# %%
model=LinearRegression()

# %%
model.fit(x,y)

# %% [markdown]
# #step3: y=mx+c in this x is new input it predicts the y and the new input is always having 2darray
#
#  * syntax:model.predict(input)

# %%
model.predict(x)

# %% [markdown]
# * we use prediction for model evaluvation and feature prediction

# %%
slope=model.coef_
slope

# %%
intercept=model.intercept_
intercept

# %% [markdown]
# * when the expereince will be 0 then slope value will be 9449.96232146 so the fresher will earn 25792.20019866871

# %%
from sklearn.model_selection import train_test_split

# %%
x=df[['YearsExperience']]
y=df['Salary']

# %%
train_test_split(x,y,train_size=0.8)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.8,random_state=40)

# %%
print(y_train)
print(y_test)
print(y_train.shape)
print(x_test)
print(y_test)

# %%
model.fit(x_train,y_train)

# %%
y_pred=model.predict(x_train)

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import root_mean_squared_error
from sklearn.metrics import r2_score

# %%
y_pred_train=model.predict(x_train)

# %%
score = r2_score(y_train, y_pred_train)
print(score)

# %%
y_pred_train=model.predict(x_test)

# %%
score = r2_score(y_train, y_pred_train)
print(score)
